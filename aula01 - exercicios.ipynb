# %% [markdown]
# #### Alguns atalhos bons:
#
# - `Ctrl+Enter` executa a celula;
# - `Alt+Enter` executa a célula e cria uma nova a baixo;
# - `Shift+Enter` executa a célula, cria uma nova a baixo foca nesta;
# - `Ctrl+M M` transforma célula de código em texto (markdown);
# - `Ctrl+M Y` transforma célula de texto em código.

# %%
# O que são variáveis?

# O sinal de  "igual" (=) a partir de agora é "recebe"

# %%
# Tipos básicos de variávies

# %%
134
# Out:
# 134

# %%
# número float

# %%
1.33333333333333
# Out:
# 1.33333333333333

# %%
1e3
# Out:
# 1000.0

# %%
1e-3
# Out:
# 0.001

# %%
1e-8
# Out:
# 1e-08

# %%
 # Número inteiro
# int

# %%
# Número float 
# float

# %%
# texto
# string

# %%
# Variável do tipo lógica
# booleana

# %% [markdown]
# # Ordem das operações matemáticas
#
# 1. Potências
# 2. Multiplicação / divisão
# 3. Soma / Subtração
#
# Só usamos parenteses

# %% [markdown]
# # Exercício 1:
#
# Crie um programa que recebe seu nome e te dê boas vindas!

# %% [markdown]
# # Exercício 2:
#
# Crie um cadastro que recebe nome, telefone e retorna eles em tela ao final.

# %% [markdown]
# - Estrutura condicional e controle de fluxo
# - Comando `if`;
# - Comando `else`;
# - Comando `elif`.

# %% [markdown]
# # Exercício 3
#
# Crie um programa que receba um número e imprima "fizz" se o número for múltiplo de 3, "buzz" for multiplo de 2 e "fizzbuzz" se for multiplo de 3 e 2 simultaneamente.

# %% [markdown]
# # Exercício 4:
#
# Faça um Programa que peça dois números e imprima o maior deles.

# %% [markdown]
# # Exercício 5
#
# Faça um Programa que verifique se uma letra digitada é "F" ou "M". Conforme a letra escrever: F - Feminino, M - Masculino, Sexo Inválido.

# %% [markdown]
# # Exercício 6 (bonus):
#
# Você quer pintar sua casa e está em dúvida entre as cores Azul, Vermelho e Magenta. Sabendo que a tinta Azul custa 25,00 reais por metro quadrado, Vermelho custa 35,00 reais por metro quadrado e Magenta custa 45,00 reais por metro quadrado, faça o seguinte:
#
# a) Crie um programa que recebe metros quadrados da sua parede e a cor da tinta e então retorne quanto gastará com tinta.
#
# b) Crie um programa que recebe largura, altura, número de paredes e a cor da tinta escolhida e então retorne quanto gastará com tinta.
